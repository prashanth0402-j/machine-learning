# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("//content/test_energy_data.csv")
data.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential           24563                   15                4
# 1    Commercial           27583                   56               23
# 2    Commercial           45313                    4               44
# 3   Residential           41625                   84               17
# 4   Residential           36720                   58               47
#
#    Average Temperature Day of Week  Energy Consumption
# 0                28.52     Weekday             2865.57
# 1                23.07     Weekend             4283.80
# 2                33.56     Weekday             5067.83
# 3                27.39     Weekend             4624.30
# 4                17.08     Weekday             4820.59

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

sns.scatterplot(x="Average Temperature",y="Energy Consumption",data=data)
plt.show()

# %%
x=data["Average Temperature"].values.reshape(-1,1)
y=data["Energy Consumption"].values.reshape(-1,1)
#print(x,y)
clf = LinearRegression()
clf.fit(x,y)
print(clf.score(x,y)*100)
# Out:
# 0.635737486877963

# %%
print(clf.predict([[28.52]]))
# Out:
# [[4125.78708047]]

# %%
plt.scatter(x,y)
plt.plot(x,clf.predict(x),color='blue')
plt.show()
