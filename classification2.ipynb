# %%
from pandas import read_csv
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import tree

dataframe = read_csv("/content/TechCorner_Sales_update.csv")
dataframe.head()
# Out:
#    Cus.ID        Date      Cus. Location  Age Gender              Mobile Name  \
# 0       1  27-05-2024    Rangamati Sadar   49      F      Galaxy A55 5G 8/128
# 1       2  27-05-2024   Inside Rangamati   44      M  Redmi Note 12 Pro 8/128
# 2       3  27-05-2024    Rangamati Sadar   45      M      R-70 Turbo 5G 6/128
# 3       4  27-05-2024    Rangamati Sadar   46      M      R-70 Turbo 5G 6/128
# 4       5  27-05-2024  Outside Rangamati   27      F        Vivo T3x 5G 8/128
#
#    Sell Price Does he/she Come from Facebook Page?  \
# 0     17073.0                                   No
# 1     15546.0                                  Yes
# 2     26516.0                                  Yes
# 3     21927.0                                   No
# 4     16718.0                                  Yes
#
#   Does he/she Followed Our Page? Did he/she buy any mobile before?  \
# 0                            Yes                                No
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8871 entries, 0 to 8870
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Cus.ID                                8871 non-null   int64
#  1   Date                                  8871 non-null   object
#  2   Cus. Location                         8871 non-null   object
#  3   Age                                   8871 non-null   int64
#  4   Gender                                8871 non-null   object
#  5   Mobile Name                           8871 non-null   object
#  6   Sell Price                            8871 non-null   float64
#  7   Does he/she Come from Facebook Page?  8871 non-null   object
#  8   Does he/she Followed Our Page?        8871 non-null   object
#  9   Did he/she buy any mobile before?     8871 non-null   object
#  10  Did he/she hear of our shop before?   8871 non-null   object
# ...

# %%
x=dataframe["Age"].values.reshape(-1,1)
y=dataframe["Gender"].values.ravel()
print(x,y)
# Out:
# [[49]
#  [44]
#  [45]
#  ...
#  [30]
#  [22]
#  [22]] ['F' 'M' 'M' ... 'F' 'F' 'M']

# %%
from sklearn.tree import DecisionTreeClassifier

clf=DecisionTreeClassifier()
clf.fit(x,y)
print(clf.score(x,y))
# Out:
# 0.5271108105061436

# %%
print(clf.predict([[49]]))
# Out:
# ['F']

# %%
import numpy as np
x=np.array(x)
y=np.array(y)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.10, random_state=4)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report
predictions = clf.predict(x_test)
print("precission values", predictions)
print("original value",y_test)
# Out:
# precission values ['F' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'F' 'M' 'M' 'F' 'M' 'M' 'M' 'F' 'F' 'M'
#  'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'M' 'F' 'M' 'F' 'F'
#  'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'M' 'M' 'F' 'M' 'F'
#  'F' 'F' 'F' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'M'
#  'F' 'M' 'M' 'M' 'F' 'M' 'M' 'F' 'F' 'M' 'M' 'F' 'F' 'M' 'M' 'M' 'M' 'F'
#  'M' 'M' 'M' 'F' 'F' 'F' 'M' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'F' 'F'
#  'F' 'F' 'F' 'F' 'M' 'M' 'F' 'M' 'M' 'F' 'M' 'F' 'F' 'M' 'M' 'M' 'F' 'F'
#  'F' 'F' 'F' 'M' 'M' 'M' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F'
#  'M' 'M' 'M' 'M' 'M' 'F' 'M' 'M' 'F' 'F' 'M' 'M' 'M' 'M' 'F' 'F' 'M' 'M'
#  'F' 'M' 'F' 'M' 'F' 'F' 'M' 'F' 'M' 'M' 'F' 'F' 'F' 'M' 'M' 'F' 'F' 'F'
#  'F' 'M' 'F' 'M' 'M' 'M' 'F' 'F' 'M' 'F' 'M' 'M' 'M' 'F' 'M' 'M' 'F' 'F'
#  'F' 'F' 'F' 'M' 'M' 'F' 'F' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'M' 'F' 'F' 'F'
#  'M' 'M' 'F' 'F' 'F' 'M' 'M' 'F' 'M' 'M' 'M' 'F' 'F' 'F' 'F' 'F' 'M' 'M'
# ...

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            F       0.49      0.55      0.52       429
#            M       0.52      0.46      0.49       459
#
#     accuracy                           0.50       888
#    macro avg       0.51      0.50      0.50       888
# weighted avg       0.51      0.50      0.50       888

# %%
bp = read_csv("/content/TechCorner_Sales_update.csv")
bp.head()
# Out:
#    Cus.ID        Date      Cus. Location  Age Gender              Mobile Name  \
# 0       1  27-05-2024    Rangamati Sadar   49      F      Galaxy A55 5G 8/128
# 1       2  27-05-2024   Inside Rangamati   44      M  Redmi Note 12 Pro 8/128
# 2       3  27-05-2024    Rangamati Sadar   45      M      R-70 Turbo 5G 6/128
# 3       4  27-05-2024    Rangamati Sadar   46      M      R-70 Turbo 5G 6/128
# 4       5  27-05-2024  Outside Rangamati   27      F        Vivo T3x 5G 8/128
#
#    Sell Price Does he/she Come from Facebook Page?  \
# 0     17073.0                                   No
# 1     15546.0                                  Yes
# 2     26516.0                                  Yes
# 3     21927.0                                   No
# 4     16718.0                                  Yes
#
#   Does he/she Followed Our Page? Did he/she buy any mobile before?  \
# 0                            Yes                                No
# ...

# %%
x=bp["Sell Price"].values.reshape(-1,1)
y=bp["Mobile Name"].values.ravel()

# %%
from sklearn.tree import DecisionTreeClassifier

clf=DecisionTreeClassifier()
clf.fit(x,y)
print(clf.score(x,y))
# Out:
# 0.8129861345958742

# %%
print(clf.predict([["17073.0"]]))
# Out:
# ['Galaxy A55 5G 8/128']

# %%
import numpy as np
x=np.array(x)
y=np.array(y)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=4)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report
predictions = clf.predict(x_test)
print("precission values", predictions)
print("original value",y_test)
# Out:
# precission values ['iPhone 16 Pro Max 1TB' 'Pixel 8 Pro 12/256' 'iQOO Z7 5G 6/128' ...
#  'Vivo Y200 5G 6/128' 'Galaxy A55 5G 8/128' 'Galaxy M35 5G 8/128']
# original value ['Moto G85 5G 8/128' 'R-70 Turbo 5G 6/128' 'Vivo T3x 5G 8/128' ...
#  'Moto G85 5G 8/128' 'Redmi Note 12 Pro 8/128' 'Vivo T3x 5G 8/128']

# %%
print(classification_report(y_test, predictions))
# Out:
#                           precision    recall  f1-score   support
#
#      Galaxy A55 5G 8/128       0.21      0.34      0.26        99
#      Galaxy M35 5G 8/128       0.08      0.12      0.09        95
#  Galaxy S24 Ultra 12/256       0.14      0.15      0.14       116
#        Moto G85 5G 8/128       0.14      0.13      0.13       125
#           Narzo N53 4/64       0.13      0.14      0.13       110
#           Note 11S 6/128       0.11      0.09      0.10       117
#     Note 14 Pro 5G 8/256       0.24      0.24      0.24        90
#           Pixel 7a 8/128       0.22      0.27      0.24        94
#       Pixel 8 Pro 12/256       0.13      0.10      0.11       117
#      R-70 Turbo 5G 6/128       0.10      0.09      0.09       101
#  Redmi Note 12 Pro 8/128       0.33      0.25      0.28       112
#        Vivo T3x 5G 8/128       0.15      0.11      0.13       116
#       Vivo Y200 5G 6/128       0.11      0.09      0.10       112
# ...
